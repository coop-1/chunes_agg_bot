# %%
# !pip install boto3

# %%
import boto3
import json
import pandas as pd

# %%
coop_server = 'i-0b7aa9c4f1cb5e2f6'

# %%
ec2 = boto3.client('ec2')

# %%
ec2_response = ec2.describe_instance_status(InstanceIds = ['i-0b7aa9c4f1cb5e2f6'], IncludeAllInstances = True)
ec2_df = pd.DataFrame(ec2_response['InstanceStatuses'])
ec2_df['InstanceStateCode'] = ec2_df['InstanceState'].apply(lambda x: x['Name'])
server_status = ec2_df[ec2_df['InstanceId'] == coop_server]['InstanceStateCode'][0]

# %%
ec2_df[ec2_df['InstanceId'] == coop_server]['InstanceState']
# Out:
# 0    {'Code': 80, 'Name': 'stopped'}
# Name: InstanceState, dtype: object

# %%
lmbd = boto3.client('lambda')

# %%
lmbd_df = pd.DataFrame(lmbd.list_functions()['Functions'])
lmbd_df.head()
# Out:
#         FunctionName                                        FunctionArn  \
# 0  daily-new-uploads  arn:aws:lambda:us-east-2:586794463896:function...
# 1  manage_ec2_server  arn:aws:lambda:us-east-2:586794463896:function...
#
#       Runtime                                              Role  \
# 0  python3.13  arn:aws:iam::586794463896:role/super_lambda_role
# 1  python3.13  arn:aws:iam::586794463896:role/super_lambda_role
#
#                           Handler  CodeSize Description  Timeout  MemorySize  \
# 0  lambda_function.lambda_handler       942                   10         128
# 1  lambda_function.lambda_handler       355                    3         128
#
#                    LastModified                                    CodeSha256  \
# 0  2025-02-17T15:28:49.000+0000  Hvawj19YSIc/L41B6iX0aLuNiiKUBHFWEJei8WhKtEA=
# 1  2025-04-09T16:28:01.000+0000  ePm6VJTAY6KbyVK2E+XO5e8kkMyqMCqLGaS8Y35sMy4=
#
#    Version            TracingConfig                            RevisionId  \
# 0  $LATEST  {'Mode': 'PassThrough'}  b479a00f-f365-47ea-b37b-a4fe6a393567
# 1  $LATEST  {'Mode': 'PassThrough'}  8bc02dc4-270f-41a7-815a-a567e25ad1af
#
#                                               Layers PackageType  \
# 0  [{'Arn': 'arn:aws:lambda:us-east-2:33639294834...         Zip
# 1                                                NaN         Zip
#
#   Architectures EphemeralStorage  \
# 0      [x86_64]    {'Size': 512}
# 1      [x86_64]    {'Size': 512}
#
#                                           SnapStart  \
# 0  {'ApplyOn': 'None', 'OptimizationStatus': 'Off'}
# 1  {'ApplyOn': 'None', 'OptimizationStatus': 'Off'}
#
#                                        LoggingConfig
# 0  {'LogFormat': 'Text', 'LogGroup': '/aws/lambda...
# 1  {'LogFormat': 'Text', 'LogGroup': '/aws/lambda...

# %%
arn = lmbd_df[lmbd_df['FunctionName'] == 'manage_ec2_server'].iloc[0,1]

# %%
action_json = json.dumps({
    'instance_id': coop_server
    ,'action': 'start'
})

# %%
lambda_respnse = lmbd.invoke(FunctionName = arn, Payload = action_json)

# %%
with open('file.txt','wb') as lambda_response:
    lambda_response.write(lambda_respnse['Payload'].read())
